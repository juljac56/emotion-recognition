# %%
import cv2

# %%
img = cv2.imread('angry.jpeg')

# %%
import matplotlib.pyplot as plt
from deepface import DeepFace

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
from pathlib import Path
home = str(Path.home())
print("HOME_FOLDER is ",home)

predictions = DeepFace.analyze(img)
predictions
# Out:
# HOME_FOLDER is  C:\Users\julja
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:03<00:00,  1.08it/s]
# {'emotion': {'angry': 99.96788501739502,
#   'disgust': 2.2333454971663997e-20,
#   'fear': 0.03210438881069422,
#   'happy': 4.2170496661450476e-13,
#   'sad': 1.3413657029559545e-05,
#   'surprise': 3.5672151294574835e-20,
#   'neutral': 2.064419192234282e-13},
#  'dominant_emotion': 'angry',
#  'age': 29,
#  'gender': 'Man',
#  'race': {'asian': 0.025071724667213857,
#   'indian': 0.014499058306682855,
#   'black': 0.0014739236576133408,
#   'white': 96.0103988647461,
#   'middle eastern': 1.8453652039170265,
#   'latino hispanic': 2.1031925454735756},
#  'dominant_race': 'white'}

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(gray, 1.1,4)

for (x, y, w,h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
